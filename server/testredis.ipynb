# %%
#import takePic
#import client
#import blink
#import licenceplateML
#import barrier
##import time
import redis
#import parking
import io
import base64

# %%
r = redis.Redis(host="54.173.237.181", port=6379)#ip=
print(r.get('a'))
name='image2.jpg'
with open(name,"rb") as imageFile:
                  
    str=base64.b64encode(imageFile.read())
    print(str)
    r.set('pic',str)
    print('seted pic')
    #a=r.get('pic')
# Out:
# None
# b'...'
# seted pic

# %%
#r = redis.Redis()
name='testpic5.jpg'

im=r.get('pic')
im=im.decode('utf-8')
im=base64.b64decode(im)
fh = open(name, "wb")
fh.write(im)
fh.close()

# %%
im=r.get('pic')

# %%
print(im)
print(str(im.decode('utf-8')))
im=im.decode('utf-8')

# %%
im=base64.b64decode(im)
print(im)

# %%
fh = open('testpic2.jpg', "wb")
fh.write(im)
fh.close()

# %%
def main():
      name='pic.jpg'
      print('start server')
      #gate=barrier.Barrier()
      r = redis.Redis(host="54.173.237.181", port=6379)#ip=3.112.247.246
      r.set('a','sss')
      #print(r.get('pic'))
      im=r.get('pic')
      print(type(im))
      
      #im=str(im)
      print(type(im))
      im=im.decode('utf-8')
      print(im)
      print(im.decode('base64'))
      fh = open('testpic.jpg', "wb")
      fh.write(im.decode('base64'))
      fh.close()

# %%
#main()
